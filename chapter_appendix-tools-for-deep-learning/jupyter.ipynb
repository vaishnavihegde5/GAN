# %%
import kagglehub
path = kagglehub.dataset_download("sauravstatthings/car-datacsv")
# Out:
# ...
# 100%|██████████| 3.77k/3.77k [00:00<00:00, 5.28MB/s]
# Extracting files...

# %%
import numpy
import pandas as pd

from google.colab import files
uploaded = files.upload()
import io

sample_dataframe_df = pd.read_csv('car data.csv')
to_compute=sample_dataframe_df['Selling_Price']
mean_value=numpy.mean(to_compute)
print(mean_value)
# Out:
#      <input type="file" id="files-2919f4ba-0a15-4c65-93d4-fcfe3e5ec928" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2919f4ba-0a15-4c65-93d4-fcfe3e5ec928">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy
import pandas as pd

from google.colab import files
uploaded = files.upload()
import io

sample_dataframe_df = pd.read_csv('car data.csv')
to_compute=sample_dataframe_df['Selling_Price']
median_value=numpy.median(to_compute)
print(median_value)
# Out:
#      <input type="file" id="files-4a4c2154-44d9-4bec-89a7-a4a0e04bc96a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a4c2154-44d9-4bec-89a7-a4a0e04bc96a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from scipy import stats
import pandas as pd

from google.colab import files
uploaded = files.upload()
import io

sample_dataframe_df = pd.read_csv('car data.csv')
to_compute=sample_dataframe_df['Selling_Price']
mode_value=stats.mode(to_compute)
print(mode_value)
# Out:
#      <input type="file" id="files-6acb0b32-ca9a-4b85-83b9-2848b66dfbc8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6acb0b32-ca9a-4b85-83b9-2848b66dfbc8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy
import pandas as pd

from google.colab import files
uploaded = files.upload()
import io

sample_dataframe_df = pd.read_csv('car data.csv')
to_compute=sample_dataframe_df['Selling_Price']
std_value=numpy.std(to_compute)
print(std_value)
# Out:
#      <input type="file" id="files-def837e1-d9eb-48ab-a4c0-3726751f7cf1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-def837e1-d9eb-48ab-a4c0-3726751f7cf1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy
import pandas as pd

from google.colab import files
uploaded = files.upload()
import io

sample_dataframe_df = pd.read_csv('car data.csv')
to_compute=sample_dataframe_df['Selling_Price']
var_value=numpy.var(to_compute)
print(var_value)
# Out:
#      <input type="file" id="files-f74e663a-8144-473e-9717-51d9cb1baafa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f74e663a-8144-473e-9717-51d9cb1baafa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy
import pandas as pd

from google.colab import files
uploaded = files.upload()
import io

sample_dataframe_df = pd.read_csv('car data.csv')
to_compute=sample_dataframe_df['Selling_Price']
percentile_value=numpy.percentile(to_compute, 95)
print(percentile_value)
# Out:
#      <input type="file" id="files-529037aa-6953-479e-83ea-d9d0cf67d313" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-529037aa-6953-479e-83ea-d9d0cf67d313">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy
big_data=numpy.random.uniform(0,10,350)
print(big_data)
# Out:
# [9.01175737e+00 3.79834440e+00 9.74676459e+00 7.91747108e-01
#  8.51131237e-01 1.44436927e+00 1.25077507e+00 7.23533834e+00
#  2.63198876e+00 3.98068733e-01 4.93665530e+00 8.32189335e+00
#  9.35749426e+00 2.87667684e+00 4.44437908e+00 4.87706359e+00
#  3.33018739e+00 1.05105385e+00 7.76459835e+00 6.70306576e-01
#  7.42999314e+00 5.61180350e+00 8.42024596e+00 6.37006418e+00
#  5.52220112e+00 5.85476156e+00 5.80547723e+00 2.57426773e+00
#  9.30891275e+00 8.76582943e+00 4.47896171e-01 1.59735274e+00
#  1.67568505e+00 9.24249362e+00 8.14082910e+00 4.80139605e+00
#  3.33346126e+00 2.00336180e+00 1.19349265e+00 2.03401484e+00
#  5.76199207e+00 9.08395352e+00 4.73166488e+00 9.42920718e+00
#  5.19652767e+00 2.54248537e+00 7.95145376e+00 9.51956654e+00
#  8.84884571e+00 1.81861496e+00 1.47190458e+00 8.91522416e+00
#  6.37966434e+00 2.78801420e+00 5.17373878e+00 3.02663675e-01
#  4.12267481e-01 5.80114618e+00 1.72398976e+00 3.61907892e+00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
sea.barplot(x='Kms_Driven',y='Selling_Price',data=sample_dataframe_df)
# Out:
#      <input type="file" id="files-23148428-0fc3-4f70-8475-a023503c3d6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-23148428-0fc3-4f70-8475-a023503c3d6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
sea.barplot(x='Kms_Driven',y='Selling_Price',hue='Year',data=sample_dataframe_df)
# Out:
#      <input type="file" id="files-c701e5be-7fc1-4a24-a8e1-ed1d853f39cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c701e5be-7fc1-4a24-a8e1-ed1d853f39cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
plot.hist(sample_dataframe_df['Selling_Price'])
# Out:
#      <input type="file" id="files-162444d8-2f4d-4a76-a4bb-192af93a4ec0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-162444d8-2f4d-4a76-a4bb-192af93a4ec0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
plot.hist(sample_dataframe_df['Selling_Price'],bins=5)
# Out:
#      <input type="file" id="files-41b486c4-f00b-4a36-b739-a3c58d6343c4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41b486c4-f00b-4a36-b739-a3c58d6343c4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
sea.distplot(sample_dataframe_df['Selling_Price'])
# Out:
#      <input type="file" id="files-d546f39d-7750-4a30-bfd7-6c315ce41f4a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d546f39d-7750-4a30-bfd7-6c315ce41f4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
sea.boxplot(sample_dataframe_df['Selling_Price'])
# Out:
#      <input type="file" id="files-795283ec-3b6c-466b-aab1-ede88254ee95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-795283ec-3b6c-466b-aab1-ede88254ee95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
plot.scatter(x=sample_dataframe_df['Selling_Price'],y=sample_dataframe_df['Kms_Driven'])
# Out:
#      <input type="file" id="files-abf9661b-c147-472b-8ef5-9af11f9fe37b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-abf9661b-c147-472b-8ef5-9af11f9fe37b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
features=['Selling_Price', 'Kms_Driven','Year']
sea.pairplot(sample_dataframe_df[features],height=3)
# Out:
#      <input type="file" id="files-047f4064-bb1d-4d2f-b405-c4f18e14ea0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-047f4064-bb1d-4d2f-b405-c4f18e14ea0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plot
import seaborn as sea
# %matplotlib inline

from google.colab import files
uploaded= files.upload()
import io
sample_dataframe_df=pd.read_csv('car data.csv')
features=['Selling_Price', 'Kms_Driven','Year']
sea.heatmap(sample_dataframe_df[features],annot=True)
# Out:
#      <input type="file" id="files-0ec1d176-7cfe-4a89-9c90-e762b19f60f6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ec1d176-7cfe-4a89-9c90-e762b19f60f6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
